# %%
# !pip install -q efficientnet

# %%
import tensorflow as tf
import numpy as np
import pickle
import cv2
from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, Conv2D,MaxPooling2D, Activation, Flatten, Dropout, Dense
# from keras.layers.convolutional import Conv2D
# from keras.layers.convolutional import MaxPooling2D
# from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os
os.listdir("/kaggle/input/customized-whole-dataset")
# Out:
# ['bd_plant_diseases_all_classes']

# %%
import os
import gc
import re

import cv2
import math
import numpy as np
import scipy as sp
import pandas as pd

import tensorflow as tf
from IPython.display import SVG
import efficientnet.tfkeras as efn
from keras.utils import plot_model
import tensorflow.keras.layers as L
from keras.utils import model_to_dot
import tensorflow.keras.backend as K
from tensorflow.keras.models import Model
from kaggle_datasets import KaggleDatasets
from tensorflow.keras.applications import NASNetMobile

import seaborn as sns
from tqdm import tqdm
import matplotlib.cm as cm
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

tqdm.pandas()
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots

np.random.seed(0)
tf.random.set_seed(0)

import warnings
warnings.filterwarnings("ignore")

# %%
EPOCHS = 100
INIT_LR = 1e-3
BS =64
default_image_size = tuple((75,75))
image_size = 0
directory_root = '/kaggle/input/customized-whole-dataset/bd_plant_diseases_all_classes'
width=75
height=75
depth=3

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None
image_list, label_list, directory_list = [], [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")

        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")

            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".jpeg") == True:
                    directory_list.append(image_directory)
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
                else:
                    print(image_directory)
    print("[INFO] Image loading completed")
except Exception as e:
    print(f"Error --- : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing EggPlant_Insect_Pest_Disease ...
# [INFO] Processing Tomato_Yellow_Leaf_Curl_Virus ...
# [INFO] Processing EggPlant_Wilt_Disease ...
# [INFO] Processing Corn_healthy ...
# [INFO] Processing Tomato_Leaf_Mold ...
# [INFO] Processing Potato_Late_blight ...
# [INFO] Processing Wheat_Yellow_Rust ...
# [INFO] Processing Tomato_Bacterial_spot ...
# [INFO] Processing Corn_Northern_Leaf_Blight ...
# [INFO] Processing Potato_healthy ...
# [INFO] Processing EggPlant_Leaf_Spot_Disease ...
# [INFO] Processing Tomato_Septoria_leaf_spot ...
# [INFO] Processing Tomato_healthy ...
# [INFO] Processing Wheat_Brown_Rust ...
# [INFO] Processing Cauliflower_Bacterial_spot_rot ...
# [INFO] Processing Cauliflower_Healthy ...
# [INFO] Processing Rice_Brown_spot ...
# [INFO] Processing Cauliflower_Black_Rot ...
# [INFO] Processing Wheat_Healthy ...
# [INFO] Processing Tomato_Early_blight ...
# [INFO] Processing Cauliflower_Downy_Mildew ...
# [INFO] Processing Tomato_Target_Spot ...
# [INFO] Processing Rice_Leaf_smut ...
# [INFO] Processing Tomato_Spider_mites Two-spotted_spider_mite ...
# [INFO] Processing EggPlant_Small_Leaf_Disease ...
# [INFO] Processing Potato_Early_blight ...
# [INFO] Processing EggPlant_Healthy_Leaf ...
# [INFO] Processing EggPlant_White_Mold_Disease ...
# [INFO] Processing Corn_Common_rust ...
# [INFO] Processing Tomato_Late_blight ...
# [INFO] Processing Corn_Cercospora_leaf_spot_(Gray_leaf_spot) ...
# [INFO] Processing Rice_Healthy ...
# [INFO] Processing EggPlant_Mosaic_Virus_Disease ...
# [INFO] Processing Tomato_mosaic_virus ...
# [INFO] Processing Rice_Bacterial_leaf_blight ...
# [INFO] Image loading completed

# %%
for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")

            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)
# Out:
# [INFO] Processing EggPlant_Insect_Pest_Disease ...
# [INFO] Processing Tomato_Yellow_Leaf_Curl_Virus ...
# [INFO] Processing EggPlant_Wilt_Disease ...
# [INFO] Processing Corn_healthy ...
# [INFO] Processing Tomato_Leaf_Mold ...
# [INFO] Processing Potato_Late_blight ...
# [INFO] Processing Wheat_Yellow_Rust ...
# [INFO] Processing Tomato_Bacterial_spot ...
# [INFO] Processing Corn_Northern_Leaf_Blight ...
# [INFO] Processing Potato_healthy ...
# [INFO] Processing EggPlant_Leaf_Spot_Disease ...
# [INFO] Processing Tomato_Septoria_leaf_spot ...
# [INFO] Processing Tomato_healthy ...
# [INFO] Processing Wheat_Brown_Rust ...
# [INFO] Processing Cauliflower_Bacterial_spot_rot ...
# [INFO] Processing Cauliflower_Healthy ...
# [INFO] Processing Rice_Brown_spot ...
# [INFO] Processing Cauliflower_Black_Rot ...
# [INFO] Processing Wheat_Healthy ...
# [INFO] Processing Tomato_Early_blight ...
# [INFO] Processing Cauliflower_Downy_Mildew ...
# [INFO] Processing Tomato_Target_Spot ...
# [INFO] Processing Rice_Leaf_smut ...
# [INFO] Processing Tomato_Spider_mites Two-spotted_spider_mite ...
# [INFO] Processing EggPlant_Small_Leaf_Disease ...
# [INFO] Processing Potato_Early_blight ...
# [INFO] Processing EggPlant_Healthy_Leaf ...
# [INFO] Processing EggPlant_White_Mold_Disease ...
# [INFO] Processing Corn_Common_rust ...
# [INFO] Processing Tomato_Late_blight ...
# [INFO] Processing Corn_Cercospora_leaf_spot_(Gray_leaf_spot) ...
# [INFO] Processing Rice_Healthy ...
# [INFO] Processing EggPlant_Mosaic_Virus_Disease ...
# [INFO] Processing Tomato_mosaic_virus ...
# [INFO] Processing Rice_Bacterial_leaf_blight ...

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)
print(label_binarizer.classes_)
# Out:
# ['Cauliflower_Bacterial_spot_rot' 'Cauliflower_Black_Rot'
#  'Cauliflower_Downy_Mildew' 'Cauliflower_Healthy'
#  'Corn_Cercospora_leaf_spot_(Gray_leaf_spot)' 'Corn_Common_rust'
#  'Corn_Northern_Leaf_Blight' 'Corn_healthy' 'EggPlant_Healthy_Leaf'
#  'EggPlant_Insect_Pest_Disease' 'EggPlant_Leaf_Spot_Disease'
#  'EggPlant_Mosaic_Virus_Disease' 'EggPlant_Small_Leaf_Disease'
#  'EggPlant_White_Mold_Disease' 'EggPlant_Wilt_Disease'
#  'Potato_Early_blight' 'Potato_Late_blight' 'Potato_healthy'
#  'Rice_Bacterial_leaf_blight' 'Rice_Brown_spot' 'Rice_Healthy'
#  'Rice_Leaf_smut' 'Tomato_Bacterial_spot' 'Tomato_Early_blight'
#  'Tomato_Late_blight' 'Tomato_Leaf_Mold' 'Tomato_Septoria_leaf_spot'
#  'Tomato_Spider_mites Two-spotted_spider_mite' 'Tomato_Target_Spot'
#  'Tomato_Yellow_Leaf_Curl_Virus' 'Tomato_healthy' 'Tomato_mosaic_virus'
#  'Wheat_Brown_Rust' 'Wheat_Healthy' 'Wheat_Yellow_Rust']

# %%
np_image_list = np.array(image_list, dtype=np.float16) / 255.0
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.15, random_state = 42)
# Out:
# [INFO] Spliting data to train, test

# %%
x_train.shape,x_test.shape
# Out:
# ((25991, 75, 75, 3), (4587, 75, 75, 3))

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2,
    zoom_range=0.2,horizontal_flip=True,
    fill_mode="nearest")

# %%
import tensorflow as tf
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor="val_loss",
                                     min_delta=0.0001,
                                     patience=10,
                                     mode="auto",
                                     verbose = 1)
]

# %%
len(image_list)
# Out:
# 30578

# %%
def Res_Plot_Test_Save(name):
    print("[INFO] Calculating model accuracy")
    scores = model.evaluate(x_test, y_test)
    print(f"Test Accuracy: {scores[1]*100}")
    print("[INFO] Saving model")
    model.save(name)

# %%
def recall_m(y_true, y_pred):
    y_true = K.cast(y_true, 'float32') 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    y_true = K.cast(y_true, 'float32') 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    y_true = K.cast(y_true, 'float32') 
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
from tensorflow.keras.applications import EfficientNetB2
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense

# Clear previous sessions
tf.keras.backend.clear_session()

# Define input shape and number of classes
input_shape = (75, 75, 3)  # Standard size for EfficientNet
n_classes = 35

# Load EfficientNetB0 with ImageNet weights
base_model = EfficientNetB2(input_shape=input_shape, include_top=False, weights='imagenet')

# Add pooling and dense layers
out = base_model.output
out = GlobalAveragePooling2D()(out)
out = Dense(128, activation='relu')(out)  # Lightweight dense layer
predictions = Dense(n_classes, activation='softmax')(out)

# Create the model
model = Model(inputs=base_model.input, outputs=predictions)

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Compile the model
opt = Adam(learning_rate=1e-4)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=['accuracy', f1_m,  precision_m, recall_m])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31790344/31790344 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# train the network
print("[INFO] training EfficientNet network...")
history = model.fit(
    aug.flow(x_train, y_train, batch_size=BS),
    validation_data=(x_test, y_test),
    steps_per_epoch=len(x_train) // BS,
    epochs=250
    )
# Out:
# [INFO] training EfficientNet network...
# Epoch 1/250
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731833702.772738     130 service.cc:145] XLA service 0x7cf8c8079870 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1731833702.772804     130 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1731833702.772810     130 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#   3/406 ━━━━━━━━━━━━━━━━━━━━ 27s 68ms/step - accuracy: 0.0095 - f1_m: 0.0000e+00 - loss: 3.5665 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00
# I0000 00:00:1731833733.607679     130 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 135s 217ms/step - accuracy: 0.1676 - f1_m: 0.0000e+00 - loss: 3.1879 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0617 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 2/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2031 - f1_m: 0.0000e+00 - loss: 2.9885 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0612 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 3/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 112ms/step - accuracy: 0.1753 - f1_m: 0.0000e+00 - loss: 3.0736 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0583 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 4/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1719 - f1_m: 0.0000e+00 - loss: 3.1626 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0580 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 5/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 112ms/step - accuracy: 0.1760 - f1_m: 0.0000e+00 - loss: 3.0706 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0589 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 6/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1719 - f1_m: 0.0000e+00 - loss: 3.1545 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0591 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 7/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - accuracy: 0.1785 - f1_m: 0.0000e+00 - loss: 3.0578 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0609 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 8/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1094 - f1_m: 0.0000e+00 - loss: 3.1140 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0612 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 9/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 112ms/step - accuracy: 0.1758 - f1_m: 0.0000e+00 - loss: 3.0664 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0559 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 10/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1562 - f1_m: 0.0000e+00 - loss: 3.1820 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0562 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 11/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - accuracy: 0.1748 - f1_m: 0.0000e+00 - loss: 3.0709 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0515 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 12/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1562 - f1_m: 0.0000e+00 - loss: 3.0803 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0516 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 13/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 112ms/step - accuracy: 0.1771 - f1_m: 0.0000e+00 - loss: 3.0683 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0501 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 14/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2500 - f1_m: 0.0000e+00 - loss: 3.0342 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0503 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 15/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 112ms/step - accuracy: 0.1778 - f1_m: 0.0000e+00 - loss: 3.0612 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0527 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 16/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1094 - f1_m: 0.0000e+00 - loss: 3.1674 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0524 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 17/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - accuracy: 0.1744 - f1_m: 0.0000e+00 - loss: 3.0581 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0483 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 18/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1719 - f1_m: 0.0000e+00 - loss: 3.0447 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0482 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 19/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 112ms/step - accuracy: 0.1767 - f1_m: 0.0000e+00 - loss: 3.0614 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0504 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 20/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1719 - f1_m: 0.0000e+00 - loss: 3.2000 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0503 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 21/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - accuracy: 0.1751 - f1_m: 0.0000e+00 - loss: 3.0619 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0478 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 22/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1094 - f1_m: 0.0000e+00 - loss: 3.2810 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0481 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 23/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 113ms/step - accuracy: 0.1777 - f1_m: 0.0000e+00 - loss: 3.0567 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0481 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 24/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2656 - f1_m: 0.0000e+00 - loss: 2.8837 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0484 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 25/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 112ms/step - accuracy: 0.1724 - f1_m: 0.0000e+00 - loss: 3.0656 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0522 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 26/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1562 - f1_m: 0.0000e+00 - loss: 3.2286 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1696 - val_f1_m: 0.0000e+00 - val_loss: 3.0514 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch
250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 45s 109ms/step - accuracy: 0.1968 - f1_m: 1.8240e-04 - loss: 3.0051 - precision_m: 0.0059 - recall_m: 9.2625e-05 - val_accuracy: 0.2136 - val_f1_m: 0.0000e+00 - val_loss: 2.9868 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 110/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2344 - f1_m: 0.0000e+00 - loss: 2.9277 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.2134 - val_f1_m: 0.0000e+00 - val_loss: 2.9911 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 111/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 45s 109ms/step - accuracy: 0.1995 - f1_m: 0.0000e+00 - loss: 3.0066 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1938 - val_f1_m: 4.2088e-04 - val_loss: 3.0279 - val_precision_m: 0.0069 - val_recall_m: 2.1701e-04
# Epoch 112/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1875 - f1_m: 0.0000e+00 - loss: 2.9822 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1988 - val_f1_m: 4.2088e-04 - val_loss: 3.0235 - val_precision_m: 0.0069 - val_recall_m: 2.1701e-04
# Epoch 113/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - accuracy: 0.1938 - f1_m: 4.5747e-05 - loss: 3.0065 - precision_m: 0.0015 - recall_m: 2.3231e-05 - val_accuracy: 0.1903 - val_f1_m: 8.4175e-04 - val_loss: 3.0323 - val_precision_m: 0.0139 - val_recall_m: 4.3403e-04
# Epoch 114/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2656 - f1_m: 0.0000e+00 - loss: 2.8907 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1807 - val_f1_m: 8.4175e-04 - val_loss: 3.0374 - val_precision_m: 0.0139 - val_recall_m: 4.3403e-04
# Epoch 115/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - accuracy: 0.1990 - f1_m: 0.0000e+00 - loss: 2.9999 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1932 - val_f1_m: 4.2088e-04 - val_loss: 3.0237 - val_precision_m: 0.0069 - val_recall_m: 2.1701e-04
# Epoch 116/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1719 - f1_m: 0.0000e+00 - loss: 3.0726 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1910 - val_f1_m: 4.2088e-04 - val_loss: 3.0248 - val_precision_m: 0.0069 - val_recall_m: 2.1701e-04
# Epoch 117/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - accuracy: 0.2000 - f1_m: 0.0000e+00 - loss: 2.9975 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1951 - val_f1_m: 8.4175e-04 - val_loss: 3.0215 - val_precision_m: 0.0139 - val_recall_m: 4.3403e-04
# Epoch 118/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2031 - f1_m: 0.0000e+00 - loss: 2.8616 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1997 - val_f1_m: 8.4175e-04 - val_loss: 3.0164 - val_precision_m: 0.0139 - val_recall_m: 4.3403e-04
# Epoch 119/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 112ms/step - accuracy: 0.1943 - f1_m: 0.0000e+00 - loss: 3.0103 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1910 - val_f1_m: 0.0013 - val_loss: 3.0283 - val_precision_m: 0.0208 - val_recall_m: 6.5104e-04
# Epoch 120/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1562 - f1_m: 0.0000e+00 - loss: 3.1074 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1910 - val_f1_m: 0.0013 - val_loss: 3.0272 - val_precision_m: 0.0208 - val_recall_m: 6.5104e-04
# Epoch 121/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 112ms/step - accuracy: 0.2011 - f1_m: 6.1145e-05 - loss: 2.9957 - precision_m: 0.0020 - recall_m: 3.1050e-05 - val_accuracy: 0.1480 - val_f1_m: 0.0038 - val_loss: 3.0480 - val_precision_m: 0.0625 - val_recall_m: 0.0020
# Epoch 122/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3125 - f1_m: 0.0000e+00 - loss: 2.6836 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1441 - val_f1_m: 0.0046 - val_loss: 3.0503 - val_precision_m: 0.0764 - val_recall_m: 0.0024
# Epoch 123/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 110ms/step - accuracy: 0.2019 - f1_m: 2.3994e-04 - loss: 2.9901 - precision_m: 0.0078 - recall_m: 1.2184e-04 - val_accuracy: 0.0580 - val_f1_m: 0.0269 - val_loss: 3.0777 - val_precision_m: 0.3681 - val_recall_m: 0.0141
# Epoch 124/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2812 - f1_m: 0.0000e+00 - loss: 2.7638 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.0523 - val_f1_m: 0.0302 - val_loss: 3.0846 - val_precision_m: 0.4097 - val_recall_m: 0.0158
# Epoch 125/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - accuracy: 0.1988 - f1_m: 0.0000e+00 - loss: 3.0003 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.2134 - val_f1_m: 4.2088e-04 - val_loss: 2.9796 - val_precision_m: 0.0069 - val_recall_m: 2.1701e-04
# Epoch 126/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1562 - f1_m: 0.0000e+00 - loss: 2.8841 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.2132 - val_f1_m: 8.4175e-04 - val_loss: 2.9844 - val_precision_m: 0.0139 - val_recall_m: 4.3403e-04
# Epoch 127/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 45s 110ms/step - accuracy: 0.1987 - f1_m: 4.1776e-05 - loss: 2.9912 - precision_m: 0.0014 - recall_m: 2.1214e-05 - val_accuracy: 0.0486 - val_f1_m: 0.0367 - val_loss: 3.1473 - val_precision_m: 0.4560 - val_recall_m: 0.0193
# Epoch 128/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1875 - f1_m: 0.0000e+00 - loss: 3.1983 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.0486 - val_f1_m: 0.0387 - val_loss: 3.1408 - val_precision_m: 0.4699 - val_recall_m: 0.0204
# Epoch 129/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 45s 110ms/step - accuracy: 0.1964 - f1_m: 2.0959e-05 - loss: 2.9888 - precision_m: 6.8117e-04 - recall_m: 1.0643e-05 - val_accuracy: 0.1875 - val_f1_m: 0.0058 - val_loss: 3.0253 - val_precision_m: 0.0833 - val_recall_m: 0.0030
# Epoch 130/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2031 - f1_m: 0.0000e+00 - loss: 3.0818 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1905 - val_f1_m: 0.0051 - val_loss: 3.0201 - val_precision_m: 0.0833 - val_recall_m: 0.0026
# Epoch 131/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 45s 110ms/step - accuracy: 0.2038 - f1_m: 5.8219e-05 - loss: 2.9780 - precision_m: 0.0019 - recall_m: 2.9564e-05 - val_accuracy: 0.0486 - val_f1_m: 0.0548 - val_loss: 3.1192 - val_precision_m: 0.5747 - val_recall_m: 0.0291
# Epoch 132/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2656 - f1_m: 0.0000e+00 - loss: 2.9092 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.0486 - val_f1_m: 0.0548 - val_loss: 3.1199 - val_precision_m: 0.5712 - val_recall_m: 0.0291
# Epoch 133/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 45s 110ms/step - accuracy: 0.2025 - f1_m: 1.7090e-04 - loss: 2.9886 - precision_m: 0.0056 - recall_m: 8.6783e-05 - val_accuracy: 0.0538 - val_f1_m: 0.0294 - val_loss: 3.0928 - val_precision_m: 0.3958 - val_recall_m: 0.0154
# Epoch 134/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1406 - f1_m: 0.0000e+00 - loss: 3.0849 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.0512 - val_f1_m: 0.0298 - val_loss: 3.0983 - val_precision_m: 0.4028 - val_recall_m: 0.0156
# Epoch 135/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 112ms/step - accuracy: 0.2003 - f1_m: 4.0341e-04 - loss: 2.9883 - precision_m: 0.0128 - recall_m: 2.0501e-04 - val_accuracy: 0.1206 - val_f1_m: 0.0348 - val_loss: 3.0466 - val_precision_m: 0.4514 - val_recall_m: 0.0182
# Epoch 136/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2344 - f1_m: 0.0000e+00 - loss: 3.0246 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1400 - val_f1_m: 0.0331 - val_loss: 3.0393 - val_precision_m: 0.4444 - val_recall_m: 0.0174
# Epoch 137/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 112ms/step - accuracy: 0.2022 - f1_m: 4.9952e-04 - loss: 2.9788 - precision_m: 0.0162 - recall_m: 2.5366e-04 - val_accuracy: 0.0532 - val_f1_m: 0.0568 - val_loss: 3.0806 - val_precision_m: 0.5851 - val_recall_m: 0.0302
# Epoch 138/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.1094 - f1_m: 0.0000e+00 - loss: 3.0611 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.0508 - val_f1_m: 0.0576 - val_loss: 3.0879 - val_precision_m: 0.5909 - val_recall_m: 0.0306
# Epoch 139/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - accuracy: 0.2061 - f1_m: 1.8464e-04 - loss: 2.9792 - precision_m: 0.0060 - recall_m: 9.3761e-05 - val_accuracy: 0.0988 - val_f1_m: 0.0567 - val_loss: 3.0598 - val_precision_m: 0.5770 - val_recall_m: 0.0302
# Epoch 140/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2969 - f1_m: 0.0000e+00 - loss: 2.7886 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.1243 - val_f1_m: 0.0552 - val_loss: 3.0503 - val_precision_m: 0.5781 - val_recall_m: 0.0293
# Epoch 141/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - accuracy: 0.2000 - f1_m: 2.1232e-04 - loss: 2.9843 - precision_m: 0.0069 - recall_m: 1.0782e-04 - val_accuracy: 0.0538 - val_f1_m: 0.0674 - val_loss: 3.1258 - val_precision_m: 0.5984 - val_recall_m: 0.0362
# Epoch 142/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.1875 - f1_m: 0.0000e+00 - loss: 3.0026 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.0521 - val_f1_m: 0.0673 - val_loss: 3.1324 - val_precision_m: 0.5914 - val_recall_m: 0.0362
# Epoch 143/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - accuracy: 0.2058 - f1_m: 6.0203e-04 - loss: 2.9730 - precision_m: 0.0185 - recall_m: 3.0622e-04 - val_accuracy: 0.0486 - val_f1_m: 0.0684 - val_loss: 3.1395 - val_precision_m: 0.5831 - val_recall_m: 0.0369
# Epoch 144/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2188 - f1_m: 0.0000e+00 - loss: 3.0655 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.0486 - val_f1_m: 0.0693 - val_loss: 3.1564 - val_precision_m: 0.5652 - val_recall_m: 0.0375
# Epoch 145/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - accuracy: 0.2054 - f1_m: 9.5864e-05 - loss: 2.9806 - precision_m: 0.0031 - recall_m: 4.8681e-05 - val_accuracy: 0.0486 - val_f1_m: 0.0710 - val_loss: 3.1476 - val_precision_m: 0.5490 - val_recall_m: 0.0386
# Epoch 146/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2188 - f1_m: 0.0000e+00 - loss: 2.9060 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.0488 - val_f1_m: 0.0705 - val_loss: 3.1307 - val_precision_m: 0.5618 - val_recall_m: 0.0382
# Epoch 147/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 110ms/step - accuracy: 0.2043 - f1_m: 7.9836e-04 - loss: 2.9760 - precision_m: 0.0234 - recall_m: 4.0667e-04 - val_accuracy: 0.0486 - val_f1_m: 0.0716 - val_loss: 3.1689 - val_precision_m: 0.5476 - val_recall_m: 0.0391
# Epoch 148/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1250 - f1_m: 0.0000e+00 - loss: 3.1500 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.0486 - val_f1_m: 0.0731 - val_loss: 3.1910 - val_precision_m: 0.5454 - val_recall_m: 0.0399
# Epoch 149/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 110ms/step - accuracy: 0.2024 - f1_m: 8.3363e-04 - loss: 2.9706 - precision_m: 0.0271 - recall_m: 4.2333e-04 - val_accuracy: 0.0493 - val_f1_m: 0.0687 - val_loss: 3.1487 - val_precision_m: 0.5681 - val_recall_m: 0.0371
# Epoch 150/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1094 - f1_m: 0.0000e+00 - loss: 3.1477 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.0512 - val_f1_m: 0.0676 - val_loss: 3.1372 - val_precision_m: 0.5796 - val_recall_m: 0.0365
# Epoch 151/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 45s 109ms/step - accuracy: 0.2048 - f1_m: 4.0831e-04 - loss: 2.9625 - precision_m: 0.0133 - recall_m: 2.0734e-04 - val_accuracy: 0.0719 - val_f1_m: 0.0641 - val_loss: 3.0836 - val_precision_m: 0.6100 - val_recall_m: 0.0343
# Epoch 152/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2500 - f1_m: 0.0000e+00 - loss: 2.8522 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.0743 - val_f1_m: 0.0645 - val_loss: 3.0815 - val_precision_m: 0.6169 - val_recall_m: 0.0345
# Epoch 153/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - accuracy: 0.2040 - f1_m: 9.4249e-04 - loss: 2.9742 - precision_m: 0.0282 - recall_m: 4.7979e-04 - val_accuracy: 0.0486 - val_f1_m: 0.0729 - val_loss: 3.1689 - val_precision_m: 0.5537 - val_recall_m: 0.0397
# Epoch 154/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1875 - f1_m: 0.0000e+00 - loss: 2.8962 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.0486 - val_f1_m: 0.0728 - val_loss: 3.1707 - val_precision_m: 0.5410 - val_recall_m: 0.0397
# Epoch 155/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 46s 110ms/step - accuracy: 0.2015 - f1_m: 0.0012 - loss: 2.9708 - precision_m: 0.0404 - recall_m: 6.3136e-04 - val_accuracy: 0.0488 - val_f1_m: 0.0730 - val_loss: 3.1560 - val_precision_m: 0.5257 - val_recall_m: 0.0399
# Epoch 156/250
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1406 - f1_m: 0.0000e+00 - loss: 3.1873 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_accuracy: 0.0486 - val_f1_m: 0.0733 - val_loss: 3.1652 - val_precision_m: 0.5266 - val_recall_m: 0.0401
# Epoch 157/250
# 344/406 ━━━━━━━━━━━━━━━━━━━━ 6s 107ms/step - accuracy: 0.2061 - f1_m: 0.0014 - loss: 2.9694 - precision_m: 0.0452 - recall_m: 7.0691e-04

# %%
# evaluate the model
loss, accuracy, f1_score, precision, recall = model.evaluate(x_test, y_test, verbose=0)
print("Accuracy: {} \nLoss:{} \nF1_score: {} \nPrecision: {} \nRecall: {}".format(accuracy, loss, f1_score, precision, recall))

# %%
history.history

# %%
from random import randint

image_dir= "/kaggle/input/customized-whole-dataset/bd_plant_diseases_all_classes/All Classes/EggPlant_Mosaic_Virus_Disease/Mosaic-Virus-1-_jpg.rf.bd82b6c570b31d283ca4af86975961e1.jpg"
print(image_dir)
index1 = image_dir.rfind('/')
index2 = image_dir.rfind('.')
Image1 = plt.imread(image_dir)

im=convert_image_to_array(image_dir)
np_image_li = np.array(im, dtype=np.float16) / 225.0
npp_image = np.expand_dims(np_image_li, axis=0)
result=model.predict(npp_image)
itemindex = np.where(result==np.max(result))
# print("probability:"+str(np.max(result))+"\n"+label_binarizer.classes_[itemindex[1][0]])
# showing image
plt.imshow(Image1)
plt.axis('off')
plt.title("Original Label: "+image_dir[index1+1:index2]+"\n"+"Predicted label: "+label_binarizer.classes_[itemindex[1][0]]+" > probability: "+str(np.max(result))[:4])
plt.show()

# %%
Res_Plot_Test_Save('XceptionNet.h5')

# %%
model_size = os.path.getsize('XceptionNet.h5')  # Size in bytes
model_size_mb = model_size / (1024 * 1024)  # Convert to MB
model_size_mb

# %%
model.summary()

# %%
import time
import numpy as np

# Convert x_test to a TensorFlow dataset for efficient batch processing
test_dataset = tf.data.Dataset.from_tensor_slices(x_test).batch(32)  # Adjust batch size as needed

# List to store inference times for each batch
inference_times = []

# Run inference on each batch in the dataset
for input_batch in test_dataset:
    start_time = time.time()
    _ = model(input_batch, training=False)  # Forward pass (inference)
    end_time = time.time()
    
    # Calculate and store time taken for this batch
    inference_times.append(end_time - start_time)

# Calculate average inference time per batch and per sample
average_inference_time_per_batch = np.mean(inference_times)
print(f"Average Inference Time per batch: {average_inference_time_per_batch:.6f} seconds")

# Per-sample inference time
batch_size = input_batch.shape[0]  # Assuming all batches are the same size
average_inference_time_per_sample = average_inference_time_per_batch / batch_size
print(f"Average Inference Time per sample: {average_inference_time_per_sample:.6f} seconds")
